# %% [markdown]
# # Baseline Model: Logistic Regression

# %% [markdown]
# ## Import Libraries and Data Loading

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd

train_df_raw = pd.read_feather('../data/processed/train_dataset.feather')
val_df_raw = pd.read_feather('../data/processed/validation_dataset.feather')

# %%
train_df_raw.head(5)
# Out:
#     index    qid1    qid2                                          question1  \
# 0   24390   45573   45574  Why do many Indians want to leave India to set...
# 1  349456  478103   52330        Is ThinkPad E series design by yamato labs?
# 2  152299  239295  239296  I have purchased a dell laptop. can anybody su...
# 3    6540   12807   12808                      Transferring to a Ivy League?
# 4  316262   65295   15140  If this question needs improvement then how ca...
#
#                                           q1_cleaned  \
# 0  why do many indian want to leave india to sett...
# 1          is thinkpad e series design by yamato lab
# 2  i have purchased a dell laptop can anybody sug...
# 3                       transferring to a ivy league
# 4  if this question need improvement then how can...
#
#                                           q2_cleaned  \
# 0             why do many indian want to leave india
# 1  how can i use pre activated jio sim in my 3g p...
# 2  what qualification should i posse to get into ...
# 3  how are mobile learning apps changing the face...
# 4  is there a way on quora to ask why a specific ...
#
#                                           q1_trimmed  \
# 0  why do many indian want to leave india to sett...
# 1          is thinkpad e series design by yamato lab
# 2  i have purchased a dell laptop can anybody sug...
# 3                       transferring to a ivy league
# 4  if this question need improvement then how can...
#
#                                           q2_trimmed      q1_start q2_start  \
# 0             why do many indian want to leave india           why      why
# 1  how can i use pre activated jio sim in my 3g p...            is      how
# 2  what qualification should i posse to get into ...             i     what
# 3  how are mobile learning apps changing the face...  transferring      how
# 4  is there a way on quora to ask why a specific ...            if       is
#
#    length_diff  lc_substring  lc_subsequence  jaccard_dist  common_words  \
# 0           17            38              38      0.653061             8
# 1           -8             2              18      0.000000             0
# 2          -58            21              54      0.139665             8
# 3          -40             5              16      0.011494             0
# 4          -24            17              31      0.168142             3
#
#    common_ratio  levenshtein  fuzz_qratio  fuzz_wratio  is_duplicate
# 0      0.086022     0.817204           82           95             1
# 1      0.000000     0.395604           39           39             0
# 2      0.037559     0.507042           50           86             0
# 3      0.000000     0.333333           33           41             0
# 4      0.020833     0.430556           43           60             1

# %% [markdown]
# ## Drop unneccessary columns

# %%
train_df = train_df_raw.drop(['index'],axis=1)
train_df.head(5)
# Out:
#    qid1  qid2                                          question1  \
# 0     1     2  What is the step by step guide to invest in sh...
# 1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2     5     6  How can I increase the speed of my internet co...
# 3     7     8  Why am I mentally very lonely? How can I solve...
# 4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  \
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
#
#                                           q1_cleaned  \
# 0  what is the step by step guide to invest in sh...
# 1     what is the story of kohinoor kohinoor diamond
# 2  how can i increase the speed of my internet co...
# 3   why am i mentally very lonely how can i solve it
# 4  which one dissolve in water quikly sugar salt ...
#
#                                           q2_cleaned q1_start q2_start  \
# 0  what is the step by step guide to invest in sh...     what     what
# 1  what would happen if the indian government sto...     what     what
# 2  how can internet speed be increased by hacking...      how      how
# 3  find the remainder when math2324math is divide...      why     find
# 4             which fish would survive in salt water    which    which
#
#    lc_substring  lc_subsequence  jaccard_dist  common_words  common_ratio
# 0            56              56      0.900602            11      0.090909
# 1            26              41      0.900602             4      0.031008
# 2            10              36      0.900602             4      0.026667
# 3             2              18      0.900602             0      0.000000
# 4             6              25      0.900602             4      0.036036
